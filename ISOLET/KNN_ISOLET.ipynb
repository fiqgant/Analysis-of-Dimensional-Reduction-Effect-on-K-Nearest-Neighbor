# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import lux
import seaborn as sn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import plot_confusion_matrix
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # KNNTanpa Reduksi

# %%
df = pd.read_csv('dataset/isolet.csv')

# %%
df.isnull().sum()
print(df.isnull().sum())

# iterating the columns 
for col in df.columns: 
    print(col)
# Out:
# X1       0
# X2       0
# X3       0
# X4       0
# X5       0
#         ..
# X614     0
# X615     0
# X616     0
# X617     0
# class    0
# Length: 618, dtype: int64
# X1
# X2
# X3
# X4
# X5
# X6
# X7
# X8
# X9
# X10
# X11
# X12
# X13
# X14
# X15
# X16
# X17
# X18
# X19
# X20
# X21
# X22
# X23
# X24
# X25
# X26
# X27
# X28
# X29
# X30
# X31
# X32
# X33
# X34
# X35
# X36
# X37
# X38
# X39
# X40
# X41
# X42
# X43
# X44
# X45
# X46
# X47
# X48
# X49
# X50
# X51
# X52
# X53
# X54
# X55
# X56
# X57
# X58
# X59
# X60
# X61
# X62
# X63
# X64
# X65
# X66
# X67
# X68
# X69
# X70
# X71
# X72
# X73
# X74
# X75
# X76
# X77
# X78
# X79
# X80
# X81
# X82
# X83
# X84
# X85
# X86
# X87
# X88
# X89
# X90
# X91
# X92
# X93
# X94
# X95
# X96
# X97
# X98
# X99
# X100
# X101
# X102
# X103
# X104
# X105
# X106
# X107
# X108
# X109
# X110
# X111
# X112
# X113
# X114
# X115
# X116
# X117
# X118
# X119
# X120
# X121
# X122
# X123
# X124
# X125
# X126
# X127
# X128
# X129
# X130
# X131
# X132
# X133
# ...

# %%
from sklearn.preprocessing import StandardScaler

X = df.iloc[:, 0:617].values
x = df.iloc[:, 0:617]
y = df.iloc[:, 617].values
y_name = df.iloc[:, 617:618]
print("X shape:",X.shape)
print("y shape:",y_name.shape)
# Out:
# X shape: (7797, 617)
# y shape: (7797, 1)

# %%
# iterating the columns 
print("Attributes:\n")
for col in x.columns: 
    print(col)

print("\n")
print("Class:")
for col in y_name.columns: 
    print(col)
# Out:
# Attributes:
#
# X1
# X2
# X3
# X4
# X5
# X6
# X7
# X8
# X9
# X10
# X11
# X12
# X13
# X14
# X15
# X16
# X17
# X18
# X19
# X20
# X21
# X22
# X23
# X24
# X25
# X26
# X27
# X28
# X29
# X30
# X31
# X32
# X33
# X34
# X35
# X36
# X37
# X38
# X39
# X40
# X41
# X42
# X43
# X44
# X45
# X46
# X47
# X48
# X49
# X50
# X51
# X52
# X53
# X54
# X55
# X56
# X57
# X58
# X59
# X60
# X61
# X62
# X63
# X64
# X65
# X66
# X67
# X68
# X69
# X70
# X71
# X72
# X73
# X74
# X75
# X76
# X77
# X78
# X79
# X80
# X81
# X82
# X83
# X84
# X85
# X86
# X87
# X88
# X89
# X90
# X91
# X92
# X93
# X94
# X95
# X96
# X97
# X98
# X99
# X100
# X101
# X102
# X103
# X104
# X105
# X106
# X107
# X108
# X109
# X110
# X111
# X112
# X113
# X114
# X115
# X116
# X117
# X118
# X119
# X120
# X121
# X122
# X123
# X124
# X125
# X126
# X127
# X128
# X129
# X130
# X131
# X132
# X133
# X134
# X135
# X136
# X137
# X138
# X139
# X140
# X141
# X142
# X143
# X144
# X145
# X146
# X147
# X148
# X149
# X150
# X151
# X152
# X153
# X154
# X155
# X156
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 100)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
KNN = KNeighborsClassifier(n_neighbors = 3, metric = 'euclidean')
KNN.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(metric='euclidean', n_neighbors=3)

# %%
y_pred_KNN = KNN.predict(X_test)

# %%
matrix = plot_confusion_matrix(KNN, X_test, y_test, cmap=plt.cm.Blues)
matrix.ax_.set_title('Confusion Matrix Logistic Reduction Tanpa Reduksi')
plt.xlabel('Prediksi')
plt.ylabel('Aktual')
plt.gcf().axes[0].tick_params
plt.gcf().axes[1].tick_params
plt.gcf().set_size_inches(20,12)
plt.show()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, matthews_corrcoef
ac  = accuracy_score(y_test, y_pred_KNN)
pre = precision_score(y_test, y_pred_KNN, average='weighted')
re  = recall_score(y_test, y_pred_KNN, average='weighted')
f1  = f1_score(y_test, y_pred_KNN, average='weighted')
mc  = matthews_corrcoef(y_test, y_pred_KNN)

# %%
np.set_printoptions()
print("Akurasi    =", ac)
print("Precison    =",pre)
print("Recall      =", re)
print("f1 score    =", f1)
print("MCC         =", mc)
# Out:
# Akurasi    = 0.8376068376068376
# Precison    = 0.8519358558833765
# Recall      = 0.8376068376068376
# f1 score    = 0.8379907475734701
# MCC         = 0.8318478436698881

# %% [markdown]
# # KNNREDUKSI LDA

# %%
LDA_d3 = pd.read_csv('dataset/isolet_after_LDA.csv')
X = LDA_d3.iloc[:, 0:25].values
x = LDA_d3.iloc[:, 0:25]
y = LDA_d3.iloc[:, 25].values
y_name = LDA_d3.iloc[:, 25:26]
print("X shape:",X.shape)
print("y shape:",y_name.shape)

# iterating the columns 
print("Attributes:\n")
for col in x.columns: 
    print(col)

print("\n")
print("Class:")
for col in y_name.columns: 
    print(col)
# Out:
# X shape: (7797, 25)
# y shape: (7797, 1)
# Attributes:
#
# LDA1
# LDA2
# LDA3
# LDA4
# LDA5
# LDA6
# LDA7
# LDA8
# LDA9
# LDA10
# LDA11
# LDA12
# LDA3.1
# LDA14
# LDA15
# LDA16
# LDA17
# LDA18
# LDA19
# LDA20
# LDA21
# LDA22
# LDA23
# LDA24
# LDA25
#
#
# Class:
# class

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 100)
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
LDA_KNN3D = KNeighborsClassifier(n_neighbors = 3, metric = 'euclidean')
LDA_KNN3D.fit(X_train, y_train)
y_pred_LDA_KNN3D = LDA_KNN3D.predict(X_test)

# %%
matrix = plot_confusion_matrix(LDA_KNN3D, X_test, y_test, cmap=plt.cm.Blues)
matrix.ax_.set_title('Confusion Matrix Reduksi LDA')
plt.xlabel('Prediksi')
plt.ylabel('Aktual')
plt.gcf().axes[0].tick_params
plt.gcf().axes[1].tick_params
plt.gcf().set_size_inches(20,12)
plt.show()

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, matthews_corrcoef
ac  = accuracy_score(y_test, y_pred_LDA_KNN3D)
pre = precision_score(y_test, y_pred_LDA_KNN3D, average='weighted')
re  = recall_score(y_test, y_pred_LDA_KNN3D, average='weighted')
f1  = f1_score(y_test, y_pred_LDA_KNN3D, average='weighted')
mc  = matthews_corrcoef(y_test, y_pred_LDA_KNN3D)  
np.set_printoptions()
print("Akurasi    =", ac)
print("Precison    =",pre)
print("Recall      =", re)
print("f1 score    =", f1)
print("MCC         =", mc)
# Out:
# Akurasi    = 0.9615384615384616
# Precison    = 0.9623754289451902
# Recall      = 0.9615384615384616
# f1 score    = 0.9616507086639652
# MCC         = 0.960006407824168

# %% [markdown]
# # KNN REDUKSI PCA

# %%
LDA_d3 = pd.read_csv('dataset/isolet_after_PCA.csv')
X = LDA_d3.iloc[:, 0:25].values
x = LDA_d3.iloc[:, 0:25]
y = LDA_d3.iloc[:, 25].values
y_name = LDA_d3.iloc[:, 25:26]
print("X shape:",X.shape)
print("y shape:",y_name.shape)

# iterating the columns 
print("Attributes:\n")
for col in x.columns: 
    print(col)

print("\n")
print("Class:")
for col in y_name.columns: 
    print(col)
# Out:
# X shape: (7797, 25)
# y shape: (7797, 1)
# Attributes:
#
# PCA1
# PCA2
# PCA3
# PCA4
# PCA5
# PCA6
# PCA7
# PCA8
# PCA9
# PCA10
# PCA11
# PCA12
# PCA3.1
# PCA14
# PCA15
# PCA16
# PCA17
# PCA18
# PCA19
# PCA20
# PCA21
# PCA22
# PCA23
# PCA24
# PCA25
#
#
# Class:
# class

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 100)
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
LDA_KNN3D = KNeighborsClassifier(n_neighbors = 3, metric = 'euclidean')
LDA_KNN3D.fit(X_train, y_train)
y_pred_LDA_KNN3D = LDA_KNN3D.predict(X_test)

# %%
matrix = plot_confusion_matrix(LDA_KNN3D, X_test, y_test, cmap=plt.cm.Blues)
matrix.ax_.set_title('Confusion Matrix Reduksi LDA')
plt.xlabel('Prediksi')
plt.ylabel('Aktual')
plt.gcf().axes[0].tick_params
plt.gcf().axes[1].tick_params
plt.gcf().set_size_inches(20,12)
plt.show()

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, matthews_corrcoef
ac  = accuracy_score(y_test, y_pred_LDA_KNN3D)
pre = precision_score(y_test, y_pred_LDA_KNN3D, average='weighted')
re  = recall_score(y_test, y_pred_LDA_KNN3D, average='weighted')
f1  = f1_score(y_test, y_pred_LDA_KNN3D, average='weighted')
mc  = matthews_corrcoef(y_test, y_pred_LDA_KNN3D)  
np.set_printoptions()
print("Akurasi    =", ac)
print("Precison    =",pre)
print("Recall      =", re)
print("f1 score    =", f1)
print("MCC         =", mc)
# Out:
# Akurasi    = 0.8115384615384615
# Precison    = 0.8285008704354551
# Recall      = 0.8115384615384615
# f1 score    = 0.8128958049413973
# MCC         = 0.8049041909244066
