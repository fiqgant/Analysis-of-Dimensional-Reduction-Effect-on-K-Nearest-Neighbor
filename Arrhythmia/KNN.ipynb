# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import lux
import seaborn as sn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import plot_confusion_matrix
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # KNNTanpa Reduksi

# %%
df = pd.read_csv('dataset/arrhythmia.csv')

# %%
df.isnull().sum()
print(df.isnull().sum())

# iterating the columns 
for col in df.columns: 
    print(col)
# Out:
# X1       0
# X2       0
# X3       0
# X4       0
# X5       0
#         ..
# X276     0
# X277     0
# X278     0
# X279     0
# class    0
# Length: 280, dtype: int64
# X1
# X2
# X3
# X4
# X5
# X6
# X7
# X8
# X9
# X10
# X11
# X12
# X13
# X14
# X15
# X16
# X17
# X18
# X19
# X20
# X21
# X22
# X23
# X24
# X25
# X26
# X27
# X28
# X29
# X30
# X31
# X32
# X33
# X34
# X35
# X36
# X37
# X38
# X39
# X40
# X41
# X42
# X43
# X44
# X45
# X46
# X47
# X48
# X49
# X50
# X51
# X52
# X53
# X54
# X55
# X56
# X57
# X58
# X59
# X60
# X61
# X62
# X63
# X64
# X65
# X66
# X67
# X68
# X69
# X70
# X71
# X72
# X73
# X74
# X75
# X76
# X77
# X78
# X79
# X80
# X81
# X82
# X83
# X84
# X85
# X86
# X87
# X88
# X89
# X90
# X91
# X92
# X93
# X94
# X95
# X96
# X97
# X98
# X99
# X100
# X101
# X102
# X103
# X104
# X105
# X106
# X107
# X108
# X109
# X110
# X111
# X112
# X113
# X114
# X115
# X116
# X117
# X118
# X119
# X120
# X121
# X122
# X123
# X124
# X125
# X126
# X127
# X128
# X129
# X130
# X131
# X132
# X133
# X134
# X135
# X136
# X137
# X138
# X139
# X140
# X141
# X142
# X143
# X144
# X145
# X146
# X147
# X148
# X149
# X150
# X151
# X152
# X153
# X154
# X155
# X156
# X157
# X158
# X159
# X160
# X161
# X162
# X163
# X164
# X165
# X166
# X167
# X168
# X169
# X170
# X171
# X172
# X173
# X174
# X175
# X176
# X177
# X178
# X179
# X180
# X181
# X182
# X183
# X184
# X185
# X186
# X187
# X188
# X189
# X190
# X191
# X192
# X193
# X194
# X195
# X196
# X197
# X198
# X199
# X200
# X201
# X202
# X203
# X204
# X205
# X206
# X207
# X208
# X209
# X210
# X211
# X212
# X213
# X214
# X215
# X216
# X217
# X218
# X219
# X220
# X221
# X222
# X223
# X224
# X225
# X226
# X227
# X228
# X229
# X230
# X231
# X232
# X233
# X234
# X235
# X236
# X237
# X238
# X239
# X240
# X241
# X242
# X243
# X244
# X245
# X246
# X247
# X248
# X249
# X250
# X251
# X252
# X253
# X254
# X255
# X256
# X257
# X258
# X259
# X260
# X261
# X262
# X263
# X264
# X265
# X266
# X267
# X268
# X269
# X270
# X271
# X272
# X273
# X274
# X275
# X276
# X277
# X278
# X279
# class

# %%
from sklearn.preprocessing import StandardScaler

X = df.iloc[:, 0:279].values
x = df.iloc[:, 0:279]
y = df.iloc[:, 279].values
y_name = df.iloc[:, 279:280]
print("X shape:",X.shape)
print("y shape:",y_name.shape)
# Out:
# X shape: (452, 279)
# y shape: (452, 1)

# %%
# iterating the columns 
print("Attributes:\n")
for col in x.columns: 
    print(col)

print("\n")
print("Class:")
for col in y_name.columns: 
    print(col)
# Out:
# Attributes:
#
# X1
# X2
# X3
# X4
# X5
# X6
# X7
# X8
# X9
# X10
# X11
# X12
# X13
# X14
# X15
# X16
# X17
# X18
# X19
# X20
# X21
# X22
# X23
# X24
# X25
# X26
# X27
# X28
# X29
# X30
# X31
# X32
# X33
# X34
# X35
# X36
# X37
# X38
# X39
# X40
# X41
# X42
# X43
# X44
# X45
# X46
# X47
# X48
# X49
# X50
# X51
# X52
# X53
# X54
# X55
# X56
# X57
# X58
# X59
# X60
# X61
# X62
# X63
# X64
# X65
# X66
# X67
# X68
# X69
# X70
# X71
# X72
# X73
# X74
# X75
# X76
# X77
# X78
# X79
# X80
# X81
# X82
# X83
# X84
# X85
# X86
# X87
# X88
# X89
# X90
# X91
# X92
# X93
# X94
# X95
# X96
# X97
# X98
# X99
# X100
# X101
# X102
# X103
# X104
# X105
# X106
# X107
# X108
# X109
# X110
# X111
# X112
# X113
# X114
# X115
# X116
# X117
# X118
# X119
# X120
# X121
# X122
# X123
# X124
# X125
# X126
# X127
# X128
# X129
# X130
# X131
# X132
# X133
# X134
# X135
# X136
# X137
# X138
# X139
# X140
# X141
# X142
# X143
# X144
# X145
# X146
# X147
# X148
# X149
# X150
# X151
# X152
# X153
# X154
# X155
# X156
# X157
# X158
# X159
# X160
# X161
# X162
# X163
# X164
# X165
# X166
# X167
# X168
# X169
# X170
# X171
# X172
# X173
# X174
# X175
# X176
# X177
# X178
# X179
# X180
# X181
# X182
# X183
# X184
# X185
# X186
# X187
# X188
# X189
# X190
# X191
# X192
# X193
# X194
# X195
# X196
# X197
# X198
# X199
# X200
# X201
# X202
# X203
# X204
# X205
# X206
# X207
# X208
# X209
# X210
# X211
# X212
# X213
# X214
# X215
# X216
# X217
# X218
# X219
# X220
# X221
# X222
# X223
# X224
# X225
# X226
# X227
# X228
# X229
# X230
# X231
# X232
# X233
# X234
# X235
# X236
# X237
# X238
# X239
# X240
# X241
# X242
# X243
# X244
# X245
# X246
# X247
# X248
# X249
# X250
# X251
# X252
# X253
# X254
# X255
# X256
# X257
# X258
# X259
# X260
# X261
# X262
# X263
# X264
# X265
# X266
# X267
# X268
# X269
# X270
# X271
# X272
# X273
# X274
# X275
# X276
# X277
# X278
# X279
#
#
# Class:
# class

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 100)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
KNN = KNeighborsClassifier(n_neighbors = 5, metric = 'euclidean')
KNN.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(metric='euclidean')

# %%
y_pred_KNN = KNN.predict(X_test)

# %%
matrix = plot_confusion_matrix(KNN, X_test, y_test, cmap=plt.cm.Blues)
matrix.ax_.set_title('Confusion Matrix Logistic Reduction Tanpa Reduksi')
plt.xlabel('Prediksi')
plt.ylabel('Aktual')
plt.gcf().axes[0].tick_params
plt.gcf().axes[1].tick_params
plt.gcf().set_size_inches(20,12)
plt.show()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, matthews_corrcoef
ac  = accuracy_score(y_test, y_pred_KNN)
pre = precision_score(y_test, y_pred_KNN, average='weighted')
re  = recall_score(y_test, y_pred_KNN, average='weighted')
f1  = f1_score(y_test, y_pred_KNN, average='weighted')
mc  = matthews_corrcoef(y_test, y_pred_KNN)

# %%
np.set_printoptions()
print("Akurasi    =", ac)
print("Precison    =",pre)
print("Recall      =", re)
print("f1 score    =", f1)
print("MCC         =", mc)
# Out:
# Akurasi    = 0.6323529411764706
# Precison    = 0.45821661998132585
# Recall      = 0.6323529411764706
# f1 score    = 0.5214962762356127
# MCC         = 0.1735880209167919

# %% [markdown]
# # KNNREDUKSI LDA

# %%
LDA_d3 = pd.read_csv('dataset/arrhythmia_after_LDA.csv')
X = LDA_d3.iloc[:, 0:12].values
x = LDA_d3.iloc[:, 0:12]
y = LDA_d3.iloc[:, 12].values
y_name = LDA_d3.iloc[:, 12:13]
print("X shape:",X.shape)
print("y shape:",y_name.shape)

# iterating the columns 
print("Attributes:\n")
for col in x.columns: 
    print(col)

print("\n")
print("Class:")
for col in y_name.columns: 
    print(col)
# Out:
# X shape: (452, 12)
# y shape: (452, 1)
# Attributes:
#
# LDA1
# LDA2
# LDA3
# LDA4
# LDA5
# LDA6
# LDA7
# LDA8
# LDA9
# LDA10
# LDA11
# LDA12
#
#
# Class:
# class

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 100)
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
LDA_KNN3D = KNeighborsClassifier(n_neighbors = 5, metric = 'euclidean')
LDA_KNN3D.fit(X_train, y_train)
y_pred_LDA_KNN3D = LDA_KNN3D.predict(X_test)

# %%
matrix = plot_confusion_matrix(LDA_KNN3D, X_test, y_test, cmap=plt.cm.Blues)
matrix.ax_.set_title('Confusion Matrix Reduksi LDA')
plt.xlabel('Prediksi')
plt.ylabel('Aktual')
plt.gcf().axes[0].tick_params
plt.gcf().axes[1].tick_params
plt.gcf().set_size_inches(20,12)
plt.show()

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, matthews_corrcoef
ac  = accuracy_score(y_test, y_pred_LDA_KNN3D)
pre = precision_score(y_test, y_pred_LDA_KNN3D, average='weighted')
re  = recall_score(y_test, y_pred_LDA_KNN3D, average='weighted')
f1  = f1_score(y_test, y_pred_LDA_KNN3D, average='weighted')
mc  = matthews_corrcoef(y_test, y_pred_LDA_KNN3D)  
np.set_printoptions()
print("Akurasi    =", ac)
print("Precison    =",pre)
print("Recall      =", re)
print("f1 score    =", f1)
print("MCC         =", mc)
# Out:
# Akurasi    = 0.9411764705882353
# Precison    = 0.908330639948287
# Recall      = 0.9411764705882353
# f1 score    = 0.9233646137418516
# MCC         = 0.8983563908812211

# %% [markdown]
# # KNN REDUKSI PCA

# %%
PCA = pd.read_csv('dataset/arrhythmia_after_PCA.csv')
X = PCA.iloc[:, 0:12].values
x = PCA.iloc[:, 0:12]
y = PCA.iloc[:, 12].values
y_name = PCA.iloc[:, 12:13]
print("X shape:",X.shape)
print("y shape:",y_name.shape)

# iterating the columns 
print("Attributes:\n")
for col in x.columns: 
    print(col)

print("\n")
print("Class:")
for col in y_name.columns: 
    print(col)
# Out:
# X shape: (452, 12)
# y shape: (452, 1)
# Attributes:
#
# PCA1
# PCA2
# PCA3
# PCA4
# PCA5
# PCA6
# PCA7
# PCA8
# PCA9
# PCA10
# PCA11
# PCA12
#
#
# Class:
# class

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 100)
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
LDA_KNN = KNeighborsClassifier(n_neighbors = 5, metric = 'euclidean')
LDA_KNN.fit(X_train, y_train)
y_pred_LDA_KNN = LDA_KNN.predict(X_test)

# %%
matrix = plot_confusion_matrix(LDA_KNN, X_test, y_test, cmap=plt.cm.Blues)
matrix.ax_.set_title('Confusion Matrix Reduksi LDA')
plt.xlabel('Prediksi')
plt.ylabel('Aktual')
plt.gcf().axes[0].tick_params
plt.gcf().axes[1].tick_params
plt.gcf().set_size_inches(20,12)
plt.show()

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, matthews_corrcoef
ac  = accuracy_score(y_test, y_pred_LDA_KNN)
pre = precision_score(y_test, y_pred_LDA_KNN, average='weighted')
re  = recall_score(y_test, y_pred_LDA_KNN, average='weighted')
f1  = f1_score(y_test, y_pred_LDA_KNN, average='weighted')
mc  = matthews_corrcoef(y_test, y_pred_LDA_KNN)  
np.set_printoptions()
print("Akurasi    =", ac)
print("Precison    =",pre)
print("Recall      =", re)
print("f1 score    =", f1)
print("MCC         =", mc)
# Out:
# Akurasi    = 0.6397058823529411
# Precison    = 0.4950578592092574
# Recall      = 0.6397058823529411
# f1 score    = 0.5388827994966101
# MCC         = 0.22128136091248796
