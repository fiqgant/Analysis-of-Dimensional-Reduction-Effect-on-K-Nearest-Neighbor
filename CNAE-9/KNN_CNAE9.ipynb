# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import lux
import seaborn as sn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import plot_confusion_matrix
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # KNNTanpa Reduksi

# %%
df = pd.read_csv('dataset/cnae9.csv')

# %%
df.isnull().sum()
print(df.isnull().sum())

# iterating the columns 
for col in df.columns: 
    print(col)
# Out:
# X1       0
# X2       0
# X3       0
# X4       0
# X5       0
#         ..
# X853     0
# X854     0
# X855     0
# X856     0
# class    0
# Length: 857, dtype: int64
# X1
# X2
# X3
# X4
# X5
# X6
# X7
# X8
# X9
# X10
# X11
# X12
# X13
# X14
# X15
# X16
# X17
# X18
# X19
# X20
# X21
# X22
# X23
# X24
# X25
# X26
# X27
# X28
# X29
# X30
# X31
# X32
# X33
# X34
# X35
# X36
# X37
# X38
# X39
# X40
# X41
# X42
# X43
# X44
# X45
# X46
# X47
# X48
# X49
# X50
# X51
# X52
# X53
# X54
# X55
# X56
# X57
# X58
# X59
# X60
# X61
# X62
# X63
# X64
# X65
# X66
# X67
# X68
# X69
# X70
# X71
# X72
# X73
# X74
# X75
# X76
# X77
# X78
# X79
# X80
# X81
# X82
# X83
# X84
# X85
# X86
# X87
# X88
# X89
# X90
# X91
# X92
# X93
# X94
# X95
# X96
# X97
# X98
# X99
# X100
# X101
# X102
# X103
# X104
# X105
# X106
# X107
# X108
# X109
# X110
# X111
# X112
# X113
# X114
# X115
# X116
# X117
# X118
# X119
# X120
# X121
# X122
# X123
# X124
# X125
# X126
# X127
# X128
# X129
# X130
# X131
# X132
# X133
# X134
# X135
# X136
# X137
# X138
# X139
# X140
# X141
# X142
# X143
# X144
# X145
# X146
# X147
# X148
# X149
# X150
# X151
# X152
# X153
# X154
# X155
# X156
# X157
# X158
# X159
# X160
# X161
# X162
# X163
# X164
# X165
# X166
# X167
# X168
# X169
# X170
# X171
# X172
# X173
# X174
# X175
# X176
# X177
# X178
# X179
# X180
# X181
# X182
# X183
# X184
# X185
# X186
# X187
# X188
# X189
# X190
# X191
# X192
# X193
# X194
# X195
# X196
# X197
# X198
# X199
# X200
# X201
# X202
# X203
# X204
# X205
# X206
# X207
# X208
# X209
# X210
# X211
# X212
# X213
# X214
# X215
# X216
# X217
# X218
# X219
# X220
# X221
# X222
# X223
# X224
# X225
# X226
# X227
# X228
# X229
# X230
# X231
# X232
# X233
# X234
# X235
# X236
# X237
# X238
# X239
# X240
# X241
# X242
# X243
# X244
# X245
# X246
# X247
# X248
# X249
# X250
# X251
# X252
# X253
# X254
# X255
# X256
# X257
# X258
# X259
# X260
# X261
# X262
# X263
# X264
# X265
# X266
# X267
# X268
# X269
# X270
# X271
# X272
# X273
# X274
# X275
# X276
# X277
# X278
# X279
# X280
# X281
# X282
# X283
# X284
# X285
# X286
# X287
# X288
# X289
# X290
# X291
# X292
# X293
# X294
# X295
# X296
# X297
# X298
# X299
# X300
# X301
# X302
# X303
# X304
# X305
# X306
# X307
# X308
# X309
# X310
# X311
# X312
# X313
# X314
# X315
# X316
# X317
# X318
# X319
# X320
# X321
# X322
# X323
# X324
# X325
# X326
# X327
# X328
# X329
# X330
# X331
# X332
# X333
# X334
# X335
# X336
# X337
# X338
# X339
# X340
# X341
# X342
# X343
# X344
# X345
# X346
# X347
# X348
# X349
# X350
# X351
# X352
# X353
# X354
# X355
# X356
# X357
# X358
# X764
# X765
# X766
# X767
# X768
# X769
# X770
# X771
# X772
# X773
# X774
# X775
# X776
# X777
# X778
# X779
# X780
# X781
# X782
# X783
# X784
# X785
# X786
# X787
# X788
# X789
# X790
# X791
# X792
# X793
# X794
# X795
# X796
# X797
# X798
# X799
# X800
# X801
# X802
# X803
# X804
# X805
# X806
# X807
# X808
# X809
# X810
# X811
# X812
# X813
# X814
# X815
# X816
# X817
# X818
# X819
# X820
# X821
# X822
# X823
# X824
# X825
# X826
# X827
# X828
# X829
# X830
# X831
# X832
# X833
# X834
# X835
# X836
# X837
# X838
# X839
# X840
# X841
# X842
# X843
# X844
# X845
# X846
# X847
# X848
# X849
# X850
# X851
# X852
# X853
# X854
# X855
# X856
# class

# %%
from sklearn.preprocessing import StandardScaler

X = df.iloc[:, 0:856].values
x = df.iloc[:, 0:856]
y = df.iloc[:, 856].values
y_name = df.iloc[:, 856:857]
print("X shape:",X.shape)
print("y shape:",y_name.shape)
# Out:
# X shape: (1080, 856)
# y shape: (1080, 1)

# %%
# iterating the columns 
print("Attributes:\n")
for col in x.columns: 
    print(col)

print("\n")
print("Class:")
for col in y_name.columns: 
    print(col)
# Out:
# Attributes:
#
# X1
# X2
# X3
# X4
# X5
# X6
# X7
# X8
# X9
# X10
# X11
# X12
# X13
# X14
# X15
# X16
# X17
# X18
# X19
# X20
# X21
# X22
# X23
# X24
# X25
# X26
# X27
# X28
# X29
# X30
# X31
# X32
# X33
# X34
# X35
# X36
# X37
# X38
# X39
# X40
# X41
# X42
# X43
# X44
# X45
# X46
# X47
# X48
# X49
# X50
# X51
# X52
# X53
# X54
# X55
# X56
# X57
# X58
# X59
# X60
# X61
# X62
# X63
# X64
# X65
# X66
# X67
# X68
# X69
# X70
# X71
# X72
# X73
# X74
# X75
# X76
# X77
# X78
# X79
# X80
# X81
# X82
# X83
# X84
# X85
# X86
# X87
# X88
# X89
# X90
# X91
# X92
# X93
# X94
# X95
# X96
# X97
# X98
# X99
# X100
# X101
# X102
# X103
# X104
# X105
# X106
# X107
# X108
# X109
# X110
# X111
# X112
# X113
# X114
# X115
# X116
# X117
# X118
# X119
# X120
# X121
# X122
# X123
# X124
# X125
# X126
# X127
# X128
# X129
# X130
# X131
# X132
# X133
# X134
# X135
# X136
# X137
# X138
# X139
# X140
# X141
# X142
# X143
# X144
# X145
# X146
# X147
# X148
# X149
# X150
# X151
# X152
# X153
# X154
# X155
# X156
# X157
# X158
# X159
# X160
# X161
# X162
# X163
# X164
# X165
# X166
# X167
# X168
# X169
# X170
# X171
# X172
# X173
# X174
# X175
# X176
# X177
# X178
# X179
# X180
# X181
# X182
# X183
# X184
# X185
# X186
# X187
# X188
# X189
# X190
# X191
# X192
# X193
# X194
# X195
# X196
# X197
# X198
# X199
# X200
# X201
# X202
# X203
# X204
# X205
# X206
# X207
# X208
# X209
# X210
# X211
# X212
# X213
# X214
# X215
# X216
# X217
# X218
# X219
# X220
# X221
# X222
# X223
# X224
# X225
# X226
# X227
# X228
# X229
# X230
# X231
# X232
# X233
# X234
# X235
# X236
# X237
# X238
# X239
# X240
# X241
# X242
# X243
# X244
# X245
# X246
# X247
# X248
# X249
# X250
# X251
# X252
# X253
# X659
# X660
# X661
# X662
# X663
# X664
# X665
# X666
# X667
# X668
# X669
# X670
# X671
# X672
# X673
# X674
# X675
# X676
# X677
# X678
# X679
# X680
# X681
# X682
# X683
# X684
# X685
# X686
# X687
# X688
# X689
# X690
# X691
# X692
# X693
# X694
# X695
# X696
# X697
# X698
# X699
# X700
# X701
# X702
# X703
# X704
# X705
# X706
# X707
# X708
# X709
# X710
# X711
# X712
# X713
# X714
# X715
# X716
# X717
# X718
# X719
# X720
# X721
# X722
# X723
# X724
# X725
# X726
# X727
# X728
# X729
# X730
# X731
# X732
# X733
# X734
# X735
# X736
# X737
# X738
# X739
# X740
# X741
# X742
# X743
# X744
# X745
# X746
# X747
# X748
# X749
# X750
# X751
# X752
# X753
# X754
# X755
# X756
# X757
# X758
# X759
# X760
# X761
# X762
# X763
# X764
# X765
# X766
# X767
# X768
# X769
# X770
# X771
# X772
# X773
# X774
# X775
# X776
# X777
# X778
# X779
# X780
# X781
# X782
# X783
# X784
# X785
# X786
# X787
# X788
# X789
# X790
# X791
# X792
# X793
# X794
# X795
# X796
# X797
# X798
# X799
# X800
# X801
# X802
# X803
# X804
# X805
# X806
# X807
# X808
# X809
# X810
# X811
# X812
# X813
# X814
# X815
# X816
# X817
# X818
# X819
# X820
# X821
# X822
# X823
# X824
# X825
# X826
# X827
# X828
# X829
# X830
# X831
# X832
# X833
# X834
# X835
# X836
# X837
# X838
# X839
# X840
# X841
# X842
# X843
# X844
# X845
# X846
# X847
# X848
# X849
# X850
# X851
# X852
# X853
# X854
# X855
# X856
#
#
# Class:
# class

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 100)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
KNN = KNeighborsClassifier(n_neighbors = 3, metric = 'euclidean')
KNN.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(metric='euclidean', n_neighbors=3)

# %%
y_pred_KNN = KNN.predict(X_test)

# %%
matrix = plot_confusion_matrix(KNN, X_test, y_test, cmap=plt.cm.Blues)
matrix.ax_.set_title('Confusion Matrix Logistic Reduction Tanpa Reduksi')
plt.xlabel('Prediksi')
plt.ylabel('Aktual')
plt.gcf().axes[0].tick_params
plt.gcf().axes[1].tick_params
plt.gcf().set_size_inches(20,12)
plt.show()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, matthews_corrcoef
ac  = accuracy_score(y_test, y_pred_KNN)
pre = precision_score(y_test, y_pred_KNN, average='weighted')
re  = recall_score(y_test, y_pred_KNN, average='weighted')
f1  = f1_score(y_test, y_pred_KNN, average='weighted')
mc  = matthews_corrcoef(y_test, y_pred_KNN)

# %%
np.set_printoptions()
print("Akurasi    =", ac)
print("Precison    =",pre)
print("Recall      =", re)
print("f1 score    =", f1)
print("MCC         =", mc)
# Out:
# Akurasi    = 0.8425925925925926
# Precison    = 0.8494924021022068
# Recall      = 0.8425925925925926
# f1 score    = 0.8408590973990142
# MCC         = 0.8238019300128595

# %% [markdown]
# # KNNREDUKSI LDA

# %%
LDA_d3 = pd.read_csv('dataset/cnae9_after_LDA.csv')
X = LDA_d3.iloc[:, 0:8].values
x = LDA_d3.iloc[:, 0:8]
y = LDA_d3.iloc[:, 8].values
y_name = LDA_d3.iloc[:, 8:9]
print("X shape:",X.shape)
print("y shape:",y_name.shape)

# iterating the columns 
print("Attributes:\n")
for col in x.columns: 
    print(col)

print("\n")
print("Class:")
for col in y_name.columns: 
    print(col)
# Out:
# X shape: (1080, 8)
# y shape: (1080, 1)
# Attributes:
#
# LDA1
# LDA2
# LDA3
# LDA4
# LDA5
# LDA6
# LDA7
# LDA8
#
#
# Class:
# class

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 100)
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
LDA_KNN3D = KNeighborsClassifier(n_neighbors = 3, metric = 'euclidean')
LDA_KNN3D.fit(X_train, y_train)
y_pred_LDA_KNN3D = LDA_KNN3D.predict(X_test)

# %%
matrix = plot_confusion_matrix(LDA_KNN3D, X_test, y_test, cmap=plt.cm.Blues)
matrix.ax_.set_title('Confusion Matrix Reduksi LDA')
plt.xlabel('Prediksi')
plt.ylabel('Aktual')
plt.gcf().axes[0].tick_params
plt.gcf().axes[1].tick_params
plt.gcf().set_size_inches(20,12)
plt.show()

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, matthews_corrcoef
ac  = accuracy_score(y_test, y_pred_LDA_KNN3D)
pre = precision_score(y_test, y_pred_LDA_KNN3D, average='weighted')
re  = recall_score(y_test, y_pred_LDA_KNN3D, average='weighted')
f1  = f1_score(y_test, y_pred_LDA_KNN3D, average='weighted')
mc  = matthews_corrcoef(y_test, y_pred_LDA_KNN3D)  
np.set_printoptions()
print("Akurasi    =", ac)
print("Precison    =",pre)
print("Recall      =", re)
print("f1 score    =", f1)
print("MCC         =", mc)
# Out:
# Akurasi    = 0.9907407407407407
# Precison    = 0.9911391132151366
# Recall      = 0.9907407407407407
# f1 score    = 0.9907747842852896
# MCC         = 0.9896138549717934

# %% [markdown]
# # KNN REDUKSI PCA

# %%
LDA_d3 = pd.read_csv('dataset/cnae9_after_PCA.csv')
X = LDA_d3.iloc[:, 0:8].values
x = LDA_d3.iloc[:, 0:8]
y = LDA_d3.iloc[:, 8].values
y_name = LDA_d3.iloc[:, 8:9]
print("X shape:",X.shape)
print("y shape:",y_name.shape)

# iterating the columns 
print("Attributes:\n")
for col in x.columns: 
    print(col)

print("\n")
print("Class:")
for col in y_name.columns: 
    print(col)
# Out:
# X shape: (1080, 8)
# y shape: (1080, 1)
# Attributes:
#
# PCA1
# PCA2
# PCA3
# PCA4
# PCA5
# PCA6
# PCA7
# PCA8
#
#
# Class:
# class

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 100)
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
LDA_KNN3D = KNeighborsClassifier(n_neighbors = 3, metric = 'euclidean')
LDA_KNN3D.fit(X_train, y_train)
y_pred_LDA_KNN3D = LDA_KNN3D.predict(X_test)

# %%
matrix = plot_confusion_matrix(LDA_KNN3D, X_test, y_test, cmap=plt.cm.Blues)
matrix.ax_.set_title('Confusion Matrix Reduksi LDA')
plt.xlabel('Prediksi')
plt.ylabel('Aktual')
plt.gcf().axes[0].tick_params
plt.gcf().axes[1].tick_params
plt.gcf().set_size_inches(20,12)
plt.show()

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, matthews_corrcoef
ac  = accuracy_score(y_test, y_pred_LDA_KNN3D)
pre = precision_score(y_test, y_pred_LDA_KNN3D, average='weighted')
re  = recall_score(y_test, y_pred_LDA_KNN3D, average='weighted')
f1  = f1_score(y_test, y_pred_LDA_KNN3D, average='weighted')
mc  = matthews_corrcoef(y_test, y_pred_LDA_KNN3D)  
np.set_printoptions()
print("Akurasi    =", ac)
print("Precison    =",pre)
print("Recall      =", re)
print("f1 score    =", f1)
print("MCC         =", mc)
# Out:
# Akurasi    = 0.7283950617283951
# Precison    = 0.7364766701398331
# Recall      = 0.7283950617283951
# f1 score    = 0.7278669407807392
# MCC         = 0.6948814930083449
